# %%
import pandas as pd
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
og_df = pd.read_csv('india.csv')
og_df = og_df.drop("AverageTemperatureUncertainty", axis=1).drop("Country", axis=1)
og_df = og_df.head(10)
og_df
# Out:
#            dt  AverageTemperature
# 0  1796-01-01              17.044
# 1  1796-02-01              19.193
# 2  1796-03-01              22.319
# 3  1796-04-01              27.233
# 4  1796-05-01              30.035
# 5  1796-06-01              29.261
# 6  1796-07-01              26.800
# 7  1796-08-01              26.558
# 8  1796-09-01              25.958
# 9  1796-10-01              24.031

# %%
og_df.iloc[0]["AverageTemperature"]
# Out:
# 17.044

# %%
# Generate Random NaNs in the dataframe
df = og_df.copy()
ix = [(row, 1) for row in range(df.shape[0]) for col in range(df.shape[1])]
for row, col in random.sample(ix, int(round(0.2*len(ix)))):
    df.iat[row, 1] = np.nan
df
# Out:
#            dt  AverageTemperature
# 0  1796-01-01                 NaN
# 1  1796-02-01              19.193
# 2  1796-03-01                 NaN
# 3  1796-04-01              27.233
# 4  1796-05-01              30.035
# 5  1796-06-01                 NaN
# 6  1796-07-01              26.800
# 7  1796-08-01              26.558
# 8  1796-09-01              25.958
# 9  1796-10-01                 NaN

# %%
# Filling method
newdf = df.interpolate()
if newdf["AverageTemperature"].isnull().values.any():
    newdf = newdf.fillna(method='bfill')
newdf
# Out:
#            dt  AverageTemperature
# 0  1796-01-01             19.1930
# 1  1796-02-01             19.1930
# 2  1796-03-01             23.2130
# 3  1796-04-01             27.2330
# 4  1796-05-01             30.0350
# 5  1796-06-01             28.4175
# 6  1796-07-01             26.8000
# 7  1796-08-01             26.5580
# 8  1796-09-01             25.9580
# 9  1796-10-01             25.9580

# %%
newset2 = df.fillna(method='ffill')
if newset2["AverageTemperature"].isnull().values.any():
    newset2 = newset2.fillna(method='bfill')
newset2
# Out:
#            dt  AverageTemperature
# 0  1796-01-01              19.193
# 1  1796-02-01              19.193
# 2  1796-03-01              19.193
# 3  1796-04-01              27.233
# 4  1796-05-01              30.035
# 5  1796-06-01              30.035
# 6  1796-07-01              26.800
# 7  1796-08-01              26.558
# 8  1796-09-01              25.958
# 9  1796-10-01              25.958

# %%
newset3 = df.fillna(method='bfill')
if newset3["AverageTemperature"].isnull().values.any():
    newset3 = newset3.fillna(method='ffill')
newset3
# Out:
#            dt  AverageTemperature
# 0  1796-01-01              19.193
# 1  1796-02-01              19.193
# 2  1796-03-01              27.233
# 3  1796-04-01              27.233
# 4  1796-05-01              30.035
# 5  1796-06-01              26.800
# 6  1796-07-01              26.800
# 7  1796-08-01              26.558
# 8  1796-09-01              25.958
# 9  1796-10-01              25.958

# %%
# Mean
meanFill = df.fillna(value=df["AverageTemperature"].mean())
meanFill
# Out:
#            dt  AverageTemperature
# 0  1796-01-01           25.962833
# 1  1796-02-01           19.193000
# 2  1796-03-01           25.962833
# 3  1796-04-01           27.233000
# 4  1796-05-01           30.035000
# 5  1796-06-01           25.962833
# 6  1796-07-01           26.800000
# 7  1796-08-01           26.558000
# 8  1796-09-01           25.958000
# 9  1796-10-01           25.962833

# %%
# Median
medianFill = df.fillna(value=df["AverageTemperature"].median())
medianFill
# Out:
#            dt  AverageTemperature
# 0  1796-01-01              26.679
# 1  1796-02-01              19.193
# 2  1796-03-01              26.679
# 3  1796-04-01              27.233
# 4  1796-05-01              30.035
# 5  1796-06-01              26.679
# 6  1796-07-01              26.800
# 7  1796-08-01              26.558
# 8  1796-09-01              25.958
# 9  1796-10-01              26.679

# %%
# Mode
modeFill = df.fillna(value=df["AverageTemperature"].mode()[0])
modeFill
# Out:
#            dt  AverageTemperature
# 0  1796-01-01              19.193
# 1  1796-02-01              19.193
# 2  1796-03-01              19.193
# 3  1796-04-01              27.233
# 4  1796-05-01              30.035
# 5  1796-06-01              19.193
# 6  1796-07-01              26.800
# 7  1796-08-01              26.558
# 8  1796-09-01              25.958
# 9  1796-10-01              19.193

# %%
# Euclidean Distance
def Euclidean_Dist(df1, df2, cols="AverageTemperature"):
    return np.linalg.norm(df1[cols].values - df2[cols].values)
data = {
    "Linear Interpolation": round(Euclidean_Dist(og_df, newdf), 3),
    "Forward Fill": round(Euclidean_Dist(og_df, newset2), 3),
    "Backward Fill": round(Euclidean_Dist(og_df, newset3), 3),
    "Mean": round(Euclidean_Dist(og_df, meanFill), 3),
    "Median": round(Euclidean_Dist(og_df, medianFill), 3),
    "Mode": round(Euclidean_Dist(og_df, modeFill), 3)
}

# %%
x = list(data.keys())
y = list(data.values())
plt.xlabel('Data Filling Method', labelpad=15, fontdict={'size': 12})
plt.ylabel('Euclidean Distance', labelpad=10, fontdict={'size': 12})
plt.title('Distance from Original', fontdict={'fontsize': 16})
ax = plt.subplot()
plt.bar(x, y)
plt.setp(ax.get_xticklabels(), rotation=30, ha='right')
plt.show()
